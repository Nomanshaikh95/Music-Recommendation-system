# %% [markdown]
# # Spotify  Recommendation  System

# %% [markdown]
# ###### Data Collection

# %%
# !pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spotipy in c:\users\admin\appdata\roaming\python\python39\site-packages (2.23.0)
# Requirement already satisfied: six>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\admin\appdata\roaming\python\python39\site-packages (from spotipy) (4.5.4)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\admin\appdata\roaming\python\python39\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Set up your Spotify API credentials
client_id = '14355fba52df430cab7d441c6df8396b'
client_secret = '9e8758a735634f099bb325f1f94d3927'

# Set up the Spotipy client
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Define a search query to find tracks
query = ['Emiway Bantai']


# Set the tracks 
max_tracks = 50

# Search for tracks
results = sp.search(q=query, type='track', limit=max_tracks)

# Extract the track IDs from the search results
track_ids = [track['id'] for track in results['tracks']['items']]

# Print the track IDs
print(track_ids)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# ['16xg7UwH9hbs96vCD8k6bC', '1eHkjvvyncnmjgwCSGI0el', '5yUxKeTYbocSVfT1BUWJpb', '1IOPDC8MVzSncKYyNaqEUS', '2FcVvA6ltdOyvP4jUgOqfa', '3LlEnO0INKAExVe4JMi7p7', '73N5AghXPjYtAoS6RIYPZd', '3gnPrVFy7vgmxw6L4UbuBE', '61eDLrQvquaTtZRnGFz9Kh', '4tCrnq1KgZy1nGch1wP5aY', '2Xv14bnP2GP8CybxqUswoK', '2YQsvNd0ZBCNXhyBTb1CqG', '3hwPiddhh4JTuCgnA9OuYS', '5jv5MBWejIF8DX9huv5tKv', '3xQOhIoKPQqimmO6nTHxwg', '4lDGoiVOnjTbsll4E2v0yG', '5FmGRiHfU52RRlaiUvhd6a', '6y7hah32ankOd6kz4nJsEv', '3jsJXCqh0NxZlpxQXsXNs5', '5IVfZKvSkv8XtlswgBcmCE', '0usNFsDDoVMYVE732zM3QI', '0TeH0rRFmef6eqk86MPyUA', '6qyacoDbIkUYXP92OtNZTA', '251VdhnEdo9kxdQ7xeGuc3', '0uxHLU2yLwnkhHcVs1HuzL', '3WT8xs1Hbo7l3YFjsUyhVs', '3SjCtYzbsVYmzfeBaaqpUd', '7BPUIl7zIezaZCuXFB7aLJ', '6ZXWOoXJo052TYQ6l0SrJf', '7wpzsG1cuzHMt9sXA62W6n', '1LYB3WsXbT6pYrlEyFEQ0d', '6bBPMpcWL9JY1kafIg0KcE', '6RjiU5upw8qutALVA3zHMq', '4qQGNeDc8ODQirpH5GS218', '0nToyYtzT9TJz6vyGfbjjv', '60ur7isIr1jFtrHIlaVX7x', '7JFaRNrpNjwxHkM8VhIiqr', '2XjiyyNS20muEJRYbZRvf5', '4oIAC4u2X5yti76y62twzs', '1khRaaP0QuGgUhKWnW6L51', '22Qz9UKeAAtGNPaMAbqT4P', '63fTryyhjbkCk8njSv4i18', '0PqxE7K26EXJY2acigxI6b', '3gouJgzxcLMhd95z9Ix6aL', '6IM3Ye50m1qHODuLTvuWWn', '1GdHmJwPl3Zg766gloSCL6', '4mD4gkg7MgbWv3FfH8Yp1O', '0tuEV5laCKscmPA9IRj9lX', '5c3wEyCcw1enilCGmC9czZ', '5TfVd7uMROQYyh6ifcKWn3']

# %%
def collect_track_data(track_id):
    track_data = sp.track(track_id)
    artists = ', '.join([artist['name'] for artist in track_data['artists']])
    album_name = track_data['album']['name']
    track_name = track_data['name']
    popularity = track_data['popularity']
    duration_ms = track_data['duration_ms']
    audio_features = sp.audio_features(track_id)[0]
    danceability = audio_features['danceability']
    energy = audio_features['energy']
    key = audio_features['key']
    loudness = audio_features['loudness']
    mode = audio_features['mode']
    speechiness = audio_features['speechiness']
    acousticness = audio_features['acousticness']
    instrumentalness = audio_features['instrumentalness']
    liveness = audio_features['liveness']
    valence = audio_features['valence']
    tempo = audio_features['tempo']
    time_signature = audio_features['time_signature']

    return [artists, album_name, track_name, popularity, duration_ms, danceability,energy  ,key, loudness, mode,
            speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]

# %%
# Initialize the collected data list
collected_data = []

# Collect data for each track ID
for track_id in track_ids:
    collected_data.append(collect_track_data(track_id))
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
for data in collected_data:
    print(data)
# Out:
# ['Emiway Bantai', 'GRIND', 'GRIND', 67, 175449, 0.848, 0.735, 1, -4.661, 1, 0.0445, 0.291, 0, 0.0713, 0.57, 98.973, 4]
# ['Emiway Bantai', 'Company', 'Company', 72, 222000, 0.778, 0.808, 7, -3.747, 1, 0.28, 0.103, 0, 0.0436, 0.602, 99.971, 4]
# ['Emiway Bantai', 'Machayenge', 'Machayenge', 62, 152142, 0.802, 0.62, 7, -9.023, 0, 0.199, 0.0172, 0, 0.0564, 0.745, 104.985, 4]
# ['Celina Sharma, Emiway Bantai', 'Jhootha', 'Jhootha', 49, 129533, 0.792, 0.743, 8, -3.25, 1, 0.0656, 0.0229, 0, 0.13, 0.464, 100.036, 4]
# ['Emiway Bantai', 'Samajh mein aaya kya?', 'Samajh mein aaya kya?', 51, 273230, 0.58, 0.452, 0, -12.446, 1, 0.335, 0.443, 0, 0.347, 0.588, 103.057, 4]
# ['Emiway Bantai', 'Khatam Hue Waande', 'Khatam Hue Waande', 60, 193882, 0.756, 0.903, 11, -2.088, 0, 0.14, 0.232, 0, 0.0548, 0.729, 99.995, 4]
# ['Emiway Bantai', 'CHUSAMBA', 'CHUSAMBA', 57, 193663, 0.777, 0.816, 7, -3.884, 1, 0.275, 0.349, 0, 0.195, 0.667, 139.68, 4]
# ['Emiway Bantai', 'Firse Machayenge', 'Firse Machayenge', 55, 207428, 0.791, 0.823, 3, -5.065, 0, 0.204, 0.294, 0, 0.0645, 0.832, 99.937, 4]
# ['Celina Sharma, Emiway Bantai', 'Lean On (with Emiway Bantai)', 'Lean On (with Emiway Bantai)', 52, 169692, 0.662, 0.716, 11, -7.047, 1, 0.0379, 0.0107, 0, 0.149, 0.385, 96.01, 4]
# ['Emiway Bantai', 'Drill', 'Drill', 56, 148333, 0.546, 0.872, 3, -4.495, 1, 0.372, 0.294, 0, 0.34, 0.714, 100.666, 3]
# ['Emiway Bantai', 'GUESS', 'GUESS', 61, 168827, 0.616, 0.916, 10, -3.234, 0, 0.258, 0.0927, 0, 0.353, 0.87, 145.39, 4]
# ['Emiway Bantai', 'Thanks To My Haters', 'Thanks To My Haters', 54, 166875, 0.592, 0.567, 1, -6.51, 0, 0.104, 0.295, 0, 0.105, 0.479, 141.84, 4]
# ['Celina Sharma, Emiway Bantai', 'Worldwide hits 8', 'Lean On', 0, 169692, 0.662, 0.716, 11, -7.047, 1, 0.0381, 0.0107, 0, 0.149, 0.384, 96.014, 4]
# ['Emiway Bantai, VAKSH', 'Monsoon', 'Kuch Aur', 41, 248175, 0.425, 0.336, 1, -12.531, 0, 0.075, 0.797, 0, 0.192, 0.376, 77.346, 4]
# ['Emiway Bantai, Macklemore', 'Firse Machayenge (Remix)', 'Firse Machayenge (Remix)', 36, 209933, 0.719, 0.759, 3, -6.59, 0, 0.261, 0.273, 0, 0.0516, 0.925, 100.212, 4]
# ['Emiway Bantai', 'Royal Rumble', 'Royal Rumble', 35, 216013, 0.583, 0.854, 10, -3.407, 0, 0.258, 0.18, 0, 0.0614, 0.323, 143.095, 4]

# %%
column_names = ['artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'danceability',
           'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
           'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# %%
for row in data:
    if len(row) != len(column_names):
        continue  # Skip the row if its length doesn't match column names
        
    # Process the row
    print("Processing row:", row)

# %%
import pandas as pd
data = pd.DataFrame(row, columns=column)

# %%
data.to_csv('spotify_rap_data.csv')

# %% [raw]
# #####

# %%
#Import Required Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score

# %%
# Load the dataset into a pandas DataFrame
data = pd.read_csv(r"C:\Users\ADMIN\OneDrive\Desktop\spotify\spotify_rap_data.csv")

# %%
# Trimming dataset
data = data.iloc[:,1:]

# %%
data.head()
# Out:
#                                              artists  \
# 0                Pritam, Mika Singh, Shefali Alvares
# 1                                         Mika Singh
# 2                                 Pritam, Mika Singh
# 3                                         Mika Singh
# 4  Neha Kakkar, Mika Singh, Kumar Sanu, Tanishk B...
#
#                     album_name                   track_name  popularity  \
# 0                    Desi Boyz             Subha Hone Na De          68
# 1                Mika Di Vohti                Mika Di Vohti          27
# 2                   Jab We Met               Mauja Hi Mauja          66
# 3               Honthon Pe Bas               Honthon Pe Bas          39
# 4  Aankh Marey (From "Simmba")  Aankh Marey (From "Simmba")          61
#
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       288696         0.727   0.900    8    -4.529     1       0.0452
# 1       208113         0.793   0.868    7    -3.815     1       0.0392
# 2       245099         0.738   0.873    2    -5.659     1       0.1070
# 3       186274         0.683   0.595    7    -7.288     0       0.0305
# 4       212741         0.796   0.978    5    -1.266     0       0.0955
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0        0.0805          0.046400     0.154    0.505  131.970               4
# 1        0.0446          0.000006     0.398    0.279  120.013               4
# 2        0.0750          0.029400     0.225    0.484  104.982               4
# 3        0.6350          0.000164     0.123    0.470  120.055               4
# 4        0.2890          0.002540     0.346    0.800  129.999               4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artists           200 non-null    object
#  1   album_name        200 non-null    object
#  2   track_name        200 non-null    object
#  3   popularity        200 non-null    int64
#  4   duration_ms       200 non-null    int64
#  5   danceability      200 non-null    float64
#  6   energy            200 non-null    float64
#  7   key               200 non-null    int64
#  8   loudness          200 non-null    float64
#  9   mode              200 non-null    int64
#  10  speechiness       200 non-null    float64
#  11  acousticness      200 non-null    float64
#  12  instrumentalness  200 non-null    float64
#  13  liveness          200 non-null    float64
#  14  valence           200 non-null    float64
#  15  tempo             200 non-null    float64
#  16  time_signature    200 non-null    int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 26.7+ KB

# %%
data.describe()
# Out:
#        popularity    duration_ms  danceability      energy         key  \
# count  200.000000     200.000000    200.000000  200.000000  200.000000
# mean    48.885000  218535.485000      0.746460    0.782635    5.050000
# std     15.093403   55212.404063      0.105754    0.132861    4.005963
# min      0.000000   86777.000000      0.410000    0.336000    0.000000
# 25%     44.000000  193495.250000      0.687000    0.716000    1.000000
# 50%     52.500000  212741.000000      0.763000    0.808500    5.000000
# 75%     58.000000  245032.000000      0.810500    0.880250    8.000000
# max     72.000000  620320.000000      0.945000    0.988000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  200.000000  200.000000   200.000000    200.000000        200.000000
# mean    -5.201910    0.575000     0.125081      0.237713          0.004251
# std      2.034282    0.495584     0.090478      0.205710          0.022979
# min    -15.326000    0.000000     0.026800      0.000521          0.000000
# 25%     -6.311500    0.000000     0.052550      0.063350          0.000000
# 50%     -4.793000    1.000000     0.088450      0.195500          0.000000
# 75%     -3.838000    1.000000     0.191250      0.366000          0.000027
# max     -1.266000    1.000000     0.409000      0.812000          0.279000
#
#          liveness     valence       tempo  time_signature
# count  200.000000  200.000000  200.000000      200.000000
# mean     0.200421    0.647082  119.333120        4.000000
# std      0.178786    0.189794   24.230119        0.265239
# min      0.029300    0.038300   74.689000        3.000000
# 25%      0.079025    0.551000   99.991750        4.000000
# 50%      0.129000    0.665500  117.958500        4.000000
# 75%      0.281250    0.788000  130.045000        4.000000
# max      0.875000    0.958000  197.954000        5.000000

# %%
# checking for missing value
data.isna().sum()
# Out:
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
# checking for duplicate value
data.duplicated().sum()
# Out:
# 50

# %%
# drop duplicate value
data.drop_duplicates()
# Out:
#                                                artists  \
# 0                  Pritam, Mika Singh, Shefali Alvares
# 1                                           Mika Singh
# 2                                   Pritam, Mika Singh
# 3                                           Mika Singh
# 4    Neha Kakkar, Mika Singh, Kumar Sanu, Tanishk B...
# ..                                                 ...
# 195                                      Emiway Bantai
# 196                       Celina Sharma, Emiway Bantai
# 197                                      Emiway Bantai
# 198                          Emiway Bantai, Macklemore
# 199                               Emiway Bantai, VAKSH
#
#                       album_name                   track_name  popularity  \
# 0                      Desi Boyz             Subha Hone Na De          68
# 1                  Mika Di Vohti                Mika Di Vohti          27
# 2                     Jab We Met               Mauja Hi Mauja          66
# 3                 Honthon Pe Bas               Honthon Pe Bas          39
# 4    Aankh Marey (From "Simmba")  Aankh Marey (From "Simmba")          61
# ..                           ...                          ...         ...
# 195              Freeverse FEAST              Freeverse FEAST          40
# 196             Worldwide hits 8                      Lean On           0
# 197                       8 Saal                       8 Saal          41
# 198     Firse Machayenge (Remix)     Firse Machayenge (Remix)          36
# 199                      Monsoon                     Kuch Aur          41
#
#      duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0         288696         0.727   0.900    8    -4.529     1       0.0452
# 1         208113         0.793   0.868    7    -3.815     1       0.0392
# 2         245099         0.738   0.873    2    -5.659     1       0.1070
# 3         186274         0.683   0.595    7    -7.288     0       0.0305
# 4         212741         0.796   0.978    5    -1.266     0       0.0955
# ..           ...           ...     ...  ...       ...   ...          ...
# 195       166390         0.730   0.835    1    -5.405     1       0.2930
# 196       169692         0.662   0.716   11    -7.047     1       0.0381
# 197       260976         0.782   0.825   10    -2.099     1       0.2610
# 198       209933         0.719   0.759    3    -6.590     0       0.2610
# 199       248175         0.425   0.336    1   -12.531     0       0.0750
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0805          0.046400    0.1540    0.505  131.970
# 1          0.0446          0.000006    0.3980    0.279  120.013
# 2          0.0750          0.029400    0.2250    0.484  104.982
# 3          0.6350          0.000164    0.1230    0.470  120.055
# 4          0.2890          0.002540    0.3460    0.800  129.999
# ..            ...               ...       ...      ...      ...
# 195        0.1540          0.000000    0.1050    0.557   85.031
# 196        0.0107          0.000000    0.1490    0.384   96.014
# 197        0.3600          0.000000    0.1670    0.438  101.368
# 198        0.2730          0.000000    0.0516    0.925  100.212
# 199        0.7970          0.000000    0.1920    0.376   77.346
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 195               4
# 196               4
# 197               4
# 198               4
# 199               4
#
# [150 rows x 17 columns]

# %%
# Feature Correlation
correlation_matrix = data.corr()

# %%
#visualisation of corealtion
plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Scale Normalization
numeric_columns = ['popularity', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode',
                   'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                   'time_signature']

scaler = StandardScaler()
data[numeric_columns] = scaler.fit_transform(data[numeric_columns])


#from sklearn.preprocessing import RobustScaler
#robust_model = RobustScaler()
#data[numeric_columns] = robust_model.fit_transform(data[numeric_columns])

# %% [markdown]
# ###### K-Means Clustering

# %%
TWSS = []
k = list(range(2, 9))

for i in k:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(data[numeric_columns])
    TWSS.append(kmeans.inertia_)

# %%
# Scree plot 
plt.plot(k, TWSS, 'ro-');plt.xlabel("No_of_Clusters");plt.ylabel("total_within_SS")
# Out:
# Text(0, 0.5, 'total_within_SS')

# %%
k = 5  # Number of clusters
kmeans = KMeans(n_clusters=k, random_state=42)
data['cluster'] = kmeans.fit_predict(data[numeric_columns])

# %%
# Find Similarity
similarity_matrix = cosine_similarity(data[numeric_columns])

# %% [markdown]
# ###### PCA

# %%
# PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data[numeric_columns])
data['PC1'] = principal_components[:, 0]
data['PC2'] = principal_components[:, 1]

# %%
# Visualization of clustering and PCA results
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=data['cluster'])
plt.show()

# %% [markdown]
# # Recommendation Function

# %%
def get_recommendations(artist_name):
    # Filter data for the given artist
    artist_data = data[data['artists'].str.contains(artist_name, case=False)]

    if artist_data.empty:
        return "No recommendations available for the given artist."

    # Find the mean popularity for each album
    album_popularity = artist_data.groupby('album_name')['popularity'].mean()

    # Find the most popular albums
    top_albums = album_popularity.nlargest(5).index.tolist()

    # Find the most similar albums
    artist_index = artist_data.index.tolist()[0]
    similarity_scores = similarity_matrix[artist_index]
    similar_albums_indices = np.argsort(similarity_scores)[::-1][1:6]
    similar_albums = data.loc[similar_albums_indices, 'album_name'].tolist()

    return top_albums ,similar_albums

# %% [markdown]
# #### Test the recommendation function

# %%
# Recommendation
artist_name = input('\nEnter artist name:  ')
top_albums , similar_albums = get_recommendations(artist_name)

print("\nTOP 5 ALBUMS: \n")
for album in top_albums:
    print(album)
    
print("\nSIMILAR ALBUMS: \n")
for album in similar_albums:
    print(album)
# Out:
# Enter artist name:  neha kakkar
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # Recommendation
#       2 artist_name = input('\nEnter artist name:  ')
# ----> 3 top_albums , similar_albums = get_recommendations(artist_name)
#       5 print("\nTOP 5 ALBUMS: \n")
#       6 for album in top_albums:
#
# NameError: name 'get_recommendations' is not defined
